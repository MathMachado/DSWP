# %% [markdown]
# <a href="https://colab.research.google.com/github/MathMachado/DSWP/blob/master/Claims.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho final
# * Estimando se o cliente terá um sinistro em 6 meses.

# %%
import pandas as pd

df = pd.read_csv('Projetos/Projeto3/train.csv')
display(df.head())
